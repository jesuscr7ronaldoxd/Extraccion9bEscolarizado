# %%
import pandas as pd

# %%
#conjunto de datos 
datos= {
    "usuario":["Ana","Luis","Martha","Crolina","Sofia","Pedro","Elena","Diego"],
    "edad":[22,35,28,40,19,31,26,45],
    "ciudad":["CDMX","Monterrey","Guadalajara","Puebla","Cancun","Merida","Tijuana","Toluca"],
     "activo":[True,False,True,False,True,False,True,False],
      "fecha_registro":["2026-01-10","2026-01-12","2025-02-18","2025-01-05","2026-07-15","2026-07-15", "2025-03-22", "2026-02-10"],
}

# %%
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#    usuario  edad       ciudad  activo fecha_registro
# 0      Ana    22         CDMX    True     2026-01-10
# 1     Luis    35    Monterrey   False     2026-01-12
# 2   Martha    28  Guadalajara    True     2025-02-18
# 3  Crolina    40       Puebla   False     2025-01-05
# 4    Sofia    19       Cancun    True     2026-07-15
# 5    Pedro    31       Merida   False     2026-07-15
# 6    Elena    26      Tijuana    True     2025-03-22
# 7    Diego    45       Toluca   False     2026-02-10

# %%
 cantidad = 1000000

# %%
import random

# %%
# datos aleatorios
nombres = ["Ana", "Luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"]
ciudades = ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancun", "Merida", "Tijuana", "Toluca"]
categorias = ["Tecnologia", "Ropa", "Hogar", "Videojuegos", "Deportes", "Calzado", "Cosmeticos", "Infantil"]

# %%
# Creacion del DataFrame
dfMillon = pd.DataFrame({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "edad" : [random.randint(18, 70) for _ in range(cantidad)],
    "salario" : [round(random.uniform(5000, 50000), 2) for _ in range(cantidad)],
    "activo" : [random.choice([True, False]) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)],
    "ciudad" : [random.choice(ciudades) for _ in range(cantidad)],
    "anio_registro" : [random.randint(2020, 2026) for _ in range(cantidad)]
})

# %%
dfMillon.dtypes
# Out:
# nombre            object
# edad               int64
# salario          float64
# activo              bool
# categoria         object
# ciudad            object
# anio_registro      int64
# dtype: object

# %%
dfMillon.memory_usage(deep=True)
# Out:
# Index                 132
# nombre           54124769
# edad              8000000
# salario           8000000
# activo            1000000
# categoria        56871151
# ciudad           55876029
# anio_registro     8000000
# dtype: int64

# %%
dfMillon.memory_usage(deep=True).sum() /1024**2
# Out:
# np.float64(182.98347568511963)
