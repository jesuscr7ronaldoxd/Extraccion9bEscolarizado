# %%
import pandas as pd

# %%
# conjunto de datos (base adaptado a Instagram)
datos = {
    "influencer": ["Ana","Luis","Martha","Carolina","Sofia","Pedro","Elena","Diego"],
    "likes": [1200, 5400, 3200, 8700, 1500, 4300, 2900, 9100],
    "comentarios": ["Me gusta", "Super", "eres grande", "todo mi estilo", "buen look", "genial", "wow", "increíble"],
    "fecha_registro": [
        "2026-01-10","2026-01-12","2025-02-18","2025-01-05",
        "2026-07-15","2026-07-15","2025-03-22","2026-02-10"
    ],
    "tipo_post": ["foto", "video", "reel", "historia", "foto", "video", "reel", "historia"]
}

# %%
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#   influencer  likes  comentarios fecha_registro tipo_post
# 0        Ana   1200          120     2026-01-10      foto
# 1       Luis   5400          540     2026-01-12     video
# 2     Martha   3200          320     2025-02-18      reel
# 3   Carolina   8700          870     2025-01-05  historia
# 4      Sofia   1500          150     2026-07-15      foto
# 5      Pedro   4300          430     2026-07-15     video
# 6      Elena   2900          290     2025-03-22      reel
# 7      Diego   9100          910     2026-02-10  historia

# %%
 cantidad = 1000000

# %%
# total de likes y comentarios
print("Total likes:", df["likes"].sum())
print("Total comentarios:", df["comentarios"].sum())
# Out:
# Total likes: 36300
# Total comentarios: 3630
